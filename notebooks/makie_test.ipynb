# %%
using GLMakie

# %%
using Plots

# %%
using Plots
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
using Plots

# %%
1+4
# Out:
# 5

# %%
try
    # put ONE failing using here, e.g.
    using GLMakie
catch err
    showerror(stderr, err, catch_backtrace())
    println("foo")
end
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
using GLMakie
# Out:
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
